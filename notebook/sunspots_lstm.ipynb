# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import MinMaxScaler
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller
from tensorflow.keras.models import Sequential, save_model
from tensorflow.keras.layers import LSTM, Dense

# %%
df=pd.read_csv("sunspots.csv")
df["Month"]=pd.to_datetime(df["Month"])
df.set_index('Month', inplace=True)
df
# Out:
#             Sunspots
# Month
# 1749-01-01      58.0
# 1749-02-01      62.6
# 1749-03-01      70.0
# 1749-04-01      55.7
# 1749-05-01      85.0
# ...              ...
# 1983-08-01      71.8
# 1983-09-01      50.3
# 1983-10-01      55.8
# 1983-11-01      33.3
# 1983-12-01      33.4
#
# [5638 rows x 1 columns]

# %%
df.dtypes
# Out:
# Sunspots    float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Sunspots    0
# dtype: int64

# %%
plt.figure(figsize = (7,7))
plt.subplot(2,1,1)
plot_acf(df['Sunspots'], lags = 40, ax = plt.gca(), title= "ACF Chart")
plt.subplot(2,1,2)
plot_pacf(df['Sunspots'], lags = 40, ax = plt.gca(), title= "PACF Chart")
plt.show()

# %%
def adf_test(dataset):
  dftest = adfuller(dataset, autolag = 'AIC')
  print("1. ADF : ",dftest[0])
  print("2. P-Value : ", dftest[1])
  print("3. Num Of Lags : ", dftest[2])
  print("4. Num Of Observations Used For ADF Regression and Critical Values Calculation :", dftest[3])
  print("5. Critical Values :")
  for key, val in dftest[4].items():
      print("\t",key, ": ", val)

# %%
adf_test(df["Sunspots"])
# Out:
# 1. ADF :  -12.789531091616915
# 2. P-Value :  7.126154827020594e-24
# 3. Num Of Lags :  33
# 4. Num Of Observations Used For ADF Regression and Critical Values Calculation : 5604
# 5. Critical Values :
# 	 1% :  -3.4315174335991756
# 	 5% :  -2.862055891650023
# 	 10% :  -2.567044607646165

# %%
train_size = int(len(df) * 0.8)
train, test = df.iloc[:train_size], df.iloc[train_size:]

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
train_date = train.index
test_date = test.index

# %%
train_values = train.values.reshape(-1, 1)
test_values = test.values.reshape(-1, 1)

# %%
train_scaled = scaler.fit_transform(train_values)
test_scaled = scaler.transform(test_values)

# %%
train_scaled = train_scaled.reshape(-1, len(train.columns))
test_scaled = test_scaled.reshape(-1, len(test.columns))

# %%
train_scaled_df = pd.DataFrame(train_scaled, columns=train.columns, index=train_date)
test_scaled_df = pd.DataFrame(test_scaled, columns=test.columns, index=test_date)

# %%
def create_sequences(data, sequence_length):
    sequences = []
    for i in range(len(data) - sequence_length + 1):
        seq = data[i:i + sequence_length]
        sequences.append(seq)
    return np.array(sequences)

# %%
sequence_length = 10
X_train = create_sequences(train_scaled_df.values, sequence_length)
X_test = create_sequences(test_scaled_df.values, sequence_length)

# %%
X_train, y_train = X_train[:, :-1], X_train[:, -1][:, -1]
X_test, y_test = X_test[:, :-1], X_test[:, -1][:, -1]

# %%
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=2)
# Out:
# Epoch 1/50
# 141/141 - 2s - loss: 0.0124 - val_loss: 0.0057 - 2s/epoch - 16ms/step
# Epoch 2/50
# 141/141 - 0s - loss: 0.0046 - val_loss: 0.0053 - 456ms/epoch - 3ms/step
# Epoch 3/50
# 141/141 - 0s - loss: 0.0044 - val_loss: 0.0050 - 440ms/epoch - 3ms/step
# Epoch 4/50
# 141/141 - 0s - loss: 0.0042 - val_loss: 0.0049 - 450ms/epoch - 3ms/step
# Epoch 5/50
# 141/141 - 0s - loss: 0.0042 - val_loss: 0.0047 - 468ms/epoch - 3ms/step
# Epoch 6/50
# 141/141 - 0s - loss: 0.0041 - val_loss: 0.0046 - 462ms/epoch - 3ms/step
# Epoch 7/50
# 141/141 - 0s - loss: 0.0040 - val_loss: 0.0046 - 472ms/epoch - 3ms/step
# Epoch 8/50
# 141/141 - 1s - loss: 0.0040 - val_loss: 0.0045 - 509ms/epoch - 4ms/step
# Epoch 9/50
# 141/141 - 1s - loss: 0.0040 - val_loss: 0.0045 - 578ms/epoch - 4ms/step
# Epoch 10/50
# 141/141 - 1s - loss: 0.0039 - val_loss: 0.0045 - 606ms/epoch - 4ms/step
# Epoch 11/50
# 141/141 - 0s - loss: 0.0039 - val_loss: 0.0046 - 467ms/epoch - 3ms/step
# Epoch 12/50
# 141/141 - 0s - loss: 0.0039 - val_loss: 0.0045 - 471ms/epoch - 3ms/step
# Epoch 13/50
# 141/141 - 0s - loss: 0.0039 - val_loss: 0.0044 - 478ms/epoch - 3ms/step
# Epoch 14/50
# 141/141 - 0s - loss: 0.0039 - val_loss: 0.0045 - 427ms/epoch - 3ms/step
# Epoch 15/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0044 - 436ms/epoch - 3ms/step
# Epoch 16/50
# 141/141 - 0s - loss: 0.0039 - val_loss: 0.0043 - 443ms/epoch - 3ms/step
# Epoch 17/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0047 - 485ms/epoch - 3ms/step
# Epoch 18/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0043 - 465ms/epoch - 3ms/step
# Epoch 19/50
# 141/141 - 0s - loss: 0.0039 - val_loss: 0.0044 - 481ms/epoch - 3ms/step
# Epoch 20/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0044 - 484ms/epoch - 3ms/step
# Epoch 21/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0047 - 496ms/epoch - 4ms/step
# Epoch 22/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0044 - 444ms/epoch - 3ms/step
# Epoch 23/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0043 - 456ms/epoch - 3ms/step
# Epoch 24/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0043 - 462ms/epoch - 3ms/step
# Epoch 25/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0043 - 441ms/epoch - 3ms/step
# Epoch 26/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0043 - 452ms/epoch - 3ms/step
# Epoch 27/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0046 - 435ms/epoch - 3ms/step
# Epoch 28/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0043 - 468ms/epoch - 3ms/step
# Epoch 29/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0044 - 455ms/epoch - 3ms/step
# Epoch 30/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0044 - 433ms/epoch - 3ms/step
# Epoch 31/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0043 - 422ms/epoch - 3ms/step
# Epoch 32/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0044 - 420ms/epoch - 3ms/step
# Epoch 33/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0043 - 420ms/epoch - 3ms/step
# Epoch 34/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0044 - 423ms/epoch - 3ms/step
# Epoch 35/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0043 - 422ms/epoch - 3ms/step
# Epoch 36/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0045 - 418ms/epoch - 3ms/step
# Epoch 37/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0043 - 430ms/epoch - 3ms/step
# Epoch 38/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0044 - 426ms/epoch - 3ms/step
# Epoch 39/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0043 - 423ms/epoch - 3ms/step
# Epoch 40/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0043 - 420ms/epoch - 3ms/step
# Epoch 41/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0043 - 422ms/epoch - 3ms/step
# Epoch 42/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0043 - 424ms/epoch - 3ms/step
# Epoch 43/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0043 - 421ms/epoch - 3ms/step
# Epoch 44/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0043 - 422ms/epoch - 3ms/step
# Epoch 45/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0045 - 468ms/epoch - 3ms/step
# Epoch 46/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0044 - 446ms/epoch - 3ms/step
# Epoch 47/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0045 - 452ms/epoch - 3ms/step
# Epoch 48/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0043 - 433ms/epoch - 3ms/step
# Epoch 49/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0043 - 420ms/epoch - 3ms/step
# Epoch 50/50
# 141/141 - 0s - loss: 0.0038 - val_loss: 0.0043 - 421ms/epoch - 3ms/step

# %%
y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'Mean Absolute Error: {mae}')
# Out:
# 35/35 [==============================] - 0s 2ms/step
# Mean Squared Error: 0.004300099200720011
# Mean Absolute Error: 0.04731520221383375

# %%
model.save(r"models/sunspots_lstm_model.h5")
# Out:
# d:\Python\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
